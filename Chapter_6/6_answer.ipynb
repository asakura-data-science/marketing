# %% [markdown]
# # 6章の章末問題解答例

# %% [markdown]
# ### (1) 相関ルールを列挙する際にいくつかの指標があるが，それらのしきい値を変更して実行すると結果がどのように変わるか確かめてみよう．具体的にはsupport値とjaccard係数の値を変更してみよう．入力ファイルはout/conv.csv or out/drug.csvを利用すればよい

# %%
import pandas as pd
import nysol.take as nt


# support値を0.1に変更して実行
nt.mtra2gc(tid='モニタ', item='細分類名', s='0.1', i='out/conv.csv', eo='out/prac1.csv').run(msg="on")
df=pd.read_csv("out/prac1.csv")
display(df)

# ドラッグストアを対象にsupport値を0.01でJaccard係数を0.3で実行（閾値を変えて実行してみよう）
nt.mtra2gc(tid='モニタ', item='細分類名', s='0.01', sim='J', th='0.3', i='out/drug.csv', eo='out/prac2.csv').run(msg="on")
df=pd.read_csv("out/prac2.csv")
display(df)

# コンビニエンスストアを対象にsupport値を0.01でJaccard係数を0.3で実行（閾値を変えて実行してみよう）
nt.mtra2gc(tid='モニタ', item='細分類名', s='0.01', sim='J', th='0.3', i='out/conv.csv', eo='out/prac3.csv').run(msg="on")
df=pd.read_csv("out/prac3.csv")
df
# Out:
# #END# mtra2gc tid=モニタ item=細分類名 s=0.1 i=out/conv.csv eo=out/prac1.csv; 2021/09/03 20:19:24
#      node1%0     node2%1  frequency  frequency1  frequency2  total   support  \
# 0    その他果実飲料  日本茶・麦茶ドリンク         86         135         326    857  0.100350
# 1       カップ麺        スナック         94         151         241    857  0.109685
# 2       カップ麺        半生菓子         90         151         246    857  0.105018
# 3       カップ麺  日本茶・麦茶ドリンク         93         151         326    857  0.108518
# 4       カップ麺        菓子パン         96         151         336    857  0.112019
# ..       ...         ...        ...         ...         ...    ...       ...
# 97        米菓        菓子パン         88         124         336    857  0.102684
# 98    紅茶ドリンク        菓子パン        121         200         336    857  0.141190
# 99      菓子パン        調理パン        178         336         227    857  0.207701
# 100     菓子パン         食パン        140         336         196    857  0.163361
# ...

# %% [markdown]
# ### (2) しきい値を変更して得られた結果をネットワークで視覚化して，コンビニエンスストアの特徴とドラッグストアの特徴を解釈してみよう．

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pathlib

def graphDraw(file):

     # 辺の情報を保存
    rsl = pd.read_csv(file)
    edge = rsl[['node1%0', 'node2%1']]
    edge.to_csv('out/edge.csv', index=False, header=False)


    # グラフの作成
    G = nx.Graph()

    # ファイルの読み込み
    G = nx.read_edgelist('out/edge.csv', delimiter=',', nodetype=str)
    print(nx.number_of_nodes(G))  # ノード数をカウントして出力
    print(nx.number_of_edges(G))  # エッジ数をカウントして出力

    # グラフ描画のレイアウトを決定。バネモデルでk=はノードの距離を決めるパラメーター
    pos = nx.spring_layout(G, k=0.6, seed=4)

    plt.figure(figsize=(15, 12))  # 図のサイズを決定 (単位はインチ)
    plt.subplots_adjust(left=0.1, right=1)
    plt.axis('off')  # 軸は描画しない
    # ノードは赤色 (r)で透過率 (alpha=)60%、エッジはシアン (c)、文字サイズ 15インチ,フォントYuGothic(Mac),MS Gothic(Win)
    nx.draw_networkx(G, pos, node_color='r', alpha=0.6,
                     edge_color='c', font_size=11, font_family='YuGothic')


graphDraw("out/prac2.csv")
graphDraw("out/prac3.csv")
# Out:
# 51
# 99
# 24
# 57

# %% [markdown]
# ### (3) スーパーマーケットとホームセンターのように同じ流通業でも商品展開や購買が異なる業態において，それらを利用する顧客のポジショニングをしたいとき，そのような評価軸がふさわしいか考えてみよう．

# %% [markdown]
# #### 解の一例：スーパーマーケットでは食品を中心とした商品展開が行われており，ホームセンターでは生活を支援する商品が主に扱われている．また，スーパーマーケットは商品単価が低く頻度の高い来店が想定されるが，ホームセンターは高額な商品も数多く取り扱っている．したがって，例えば第一軸として購買商品単価，第二軸として購買点数，もしくは第一軸として顧客の全購買のうちの食品の割合， 第二軸として購買頻度などを用いることが考えられる．

# %% [markdown]
# ### (4) 本書用に提供されている購買履歴データから本章で紹介した主成分分析と対応分析を行おう．また，このデータをもとに他に店舗の違いを分析するための変数を考えて分析しよう．

# %%
#ここでは一例として，4.1節で用いたモニタごとの購買データ(sec4-1data.csv)をもとに，主成分分析と対応分析をお行う．
#データはモニタ別，中分類名別に集計し，4章で解説したデシル分析においてデシルランク5から7のモニタのみ用いた．
#主成分分析にあたっては購買金額，対応分析にあたっては購買数量の合計をそれぞれ集計して用いている．
#いずれも上位から2軸を用いて可視化している．データの相違について十分な説明ができているかについては各自で考察せよ．

# %%
#mcaのインストール（必要ならば）
# !pip install mca
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/var/pyenv/versions/3.7.1/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
import mca
from sklearn.preprocessing import StandardScaler
import japanize_matplotlib

# %%
#主成分分析
#データの読み込み
df_decile_data = pd.read_csv('../Chapter_4/in/sec4-1data.csv')

#モニタ別金額集計
df_decile_groupby = df_decile_data.groupby('モニタ')
decile = df_decile_groupby.agg({'金額': 'sum'})

# 4.2 デシル分析の各ランクの閾値とモニタ別のランクの計算
ds = decile.reset_index(drop=True)
decile_rank, bins = pd.qcut(ds['金額'], 10, retbins=True, labels=False)
ds['rank'] = decile_rank + 1


#モニタ別・中分類名別の集計と該当なしの場合に0を代入
amount = pd.pivot_table(df_decile_data, values= '金額',  index = 'モニタ',  columns ='中分類名',  aggfunc='sum').fillna(0)

#行名を変更し，金額集計表とランクを結合
ds.index = list(amount.index)
amount2 = pd.concat([amount, ds['rank']],axis=1)

#デシル5～7のモニタのみを抽出
df_pca = amount2.query('5 <= rank <=7')

#標準化
df_pca = df_pca.drop(columns = 'rank')
scaler = StandardScaler()
pca_sc = scaler.fit_transform(df_pca)

#主成分分析の実行（主成分の数は2とした＝本来は吟味すべき）
pca_model = PCA(n_components=2)
pca_res = pca_model.fit(pca_sc)

#主成分負荷量
loading = pd.DataFrame(pca_res.components_.T)
loading.index = df_pca.columns
loading.columns = ['第1主成分', '第2主成分']

#主成分得点
score = pd.DataFrame(pca_res.fit_transform(pca_sc))
#score = pd.DataFrame(pca_res.fit_transform(df_pca.values))
score.index = df_pca.index
score.columns = ['第1主成分', '第2主成分']

#寄与率
cont_ratio = pd.DataFrame(pca_res.explained_variance_ratio_)
cum_ratio = pd.DataFrame(np.cumsum(pca_res.explained_variance_ratio_))
ratio = pd.concat([cont_ratio, cum_ratio],axis=1).T
ratio.columns = ['第1主成分', '第2主成分']
ratio.index = ['寄与率', '累積寄与率']

# %%
loading
# Out:
#                      第1主成分         第2主成分
# その他日用品        0.000000e+00  0.000000e+00
# その他食品         3.557125e-02 -7.128355e-02
# ペット用品         6.943945e-02  1.451785e-02
# 加工食品         -3.845782e-01  3.834369e-02
# 化粧品           2.827727e-01  4.181758e-01
# 家具            2.249440e-01 -1.775863e-02
# 家庭用品          3.440096e-01 -2.347310e-01
# 家電            2.790789e-01  4.693111e-01
# 寝具・寝装品        0.000000e+00  0.000000e+00
# 文具・事務用品・情報文具  2.320087e-01 -3.345995e-01
# 日用雑貨          1.611876e-01 -1.249942e-01
# 書籍           -1.488759e-01  1.108817e-01
# 玩具           -3.388132e-21  1.084202e-19
# 生鮮食品         -4.025995e-01  9.088313e-02
# 菓子類          -1.960077e-01  1.862671e-01
# 衣料・衣服        -2.999427e-01  1.047413e-01
# 車両用品          1.147944e-41  0.000000e+00
# 靴・履物          9.633927e-46 -7.882304e-46
# 飲料・酒類         3.971277e-02  1.797388e-01
# ＤＩＹ用品         2.790789e-01  4.693111e-01
# ＯＴＣ医薬品類       2.175269e-01 -3.103863e-01

# %%
score
# Out:
#         第1主成分     第2主成分
# 32  -0.551146  0.152101
# 46  -1.292065  0.520898
# 48   1.298999 -1.867775
# 49  -0.072801  1.524559
# 50   0.084446 -0.231906
# 63  -1.086258  0.210516
# 71  -2.136678  0.521497
# 75  -1.166621  0.418304
# 81   0.094905  0.023513
# 90  -1.141037  0.333474
# 95   1.537946 -0.976442
# 116  0.324961 -0.486017
# 131 -0.469152 -0.316341
# 182 -0.844385 -0.049969
# 254 -4.589731  1.507881
# 261  3.807514 -4.516313
# 288 -1.349237 -0.152129
# 292 -1.005126 -0.001333
# 307 -0.504209 -0.121346
# 392 -0.403573 -0.251548
# 431  0.612795 -0.958251
# 436 -0.034613 -0.370443
# 473 -0.046756 -0.983217
# 508  1.145488 -1.089142
# 521  3.821744 -0.267134
# 545 -1.551086 -0.070404
# 699 -0.072586  0.103585
# 763 -0.099311 -0.366081
# 946  0.794553 -0.281239
# 968  0.151539  0.981094
# 991  4.741482  7.059611

# %%
ratio
# Out:
#           第1主成分     第2主成分
# 寄与率    0.193868  0.171648
# 累積寄与率  0.193868  0.365516

# %%
#主成分負荷量のグラフ（前者が横軸，後者が縦軸）
plt.figure(figsize=(5,5))
plt.scatter(loading.values[:,0], loading.values[:,1], color='black')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.xlabel('第1主成分')
plt.ylabel('第2主成分')
for i,j in loading.iterrows():
    plt.annotate(i,xy=(j[0]+0.03, j[1]+0.03))
    
#plt.savefig('out/pca_loading12.eps', bbox_inches='tight', dpi=600)

# %%
#主成分得点のグラフ（前者が横軸，後者が縦軸）
plt.figure(figsize=(5,5))
plt.scatter(score.values[:,0], score.values[:,1], c='black', marker="x")
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.xlabel('第1主成分')
plt.ylabel('第2主成分')
for i,j in score.iterrows():
    plt.annotate(i,xy=(j[0]+0.2, j[1]+0.2))

#plt.savefig('out/pca_score12.eps', bbox_inches='tight', dpi=600)

# %%
#対応分析


#データの読み込み
df_position_org = pd.read_csv('../Chapter_4/in/sec4-1data.csv')

#小分類の購入数量を店舗ごとに集計
pt_cross_org = pd.pivot_table(df_position_org,
    values='購入数量', 
    index='中分類', 
    columns = 'モニタ', 
    aggfunc='sum'
)

# 4.2 デシル分析の各ランクの閾値とモニタ別のランクの計算
ds = decile.reset_index(drop=True)
decile_rank, bins = pd.qcut(ds['金額'], 10, retbins=True, labels=False)
ds['rank'] = decile_rank + 1

#行名を変更し，金額集計表とランクを結合
ds.index = list(amount.index)
amount2 = pd.concat([amount, ds['rank']],axis=1)

#デシル5～7のモニタのみを抽出
df_corresp = amount2.query('5 <= rank <=7').fillna(0)
df_corresp = df_corresp.drop(columns='rank')

# %%
#対応分析の実行
mca_result = mca.MCA(df_corresp, benzecri=False)
#結果
result_r = pd.DataFrame(mca_result.fs_r(N=2))
result_c = pd.DataFrame(mca_result.fs_c(N=2))
result_r.index = df_corresp.index
result_c.index = df_corresp.columns

contribution = pd.DataFrame(mca_result.expl_var(greenacre=False, N=2)).T
cum_contribution = pd.DataFrame(np.cumsum(mca_result.expl_var(greenacre=False, N=2))).T
contribution_ratio = pd.concat([contribution, cum_contribution],axis=0)
contribution_ratio.index = ['寄与率','累積寄与率']

# %%
result_r
# Out:
#             0         1
# 32   0.486349 -0.240374
# 46   0.463590 -0.232951
# 48  -0.363488  0.881621
# 49  -0.121232 -0.078198
# 50   0.497476 -0.200295
# 63   0.425664 -0.212724
# 71   0.366411 -0.307694
# 75   0.423210 -0.190848
# 81   0.499807 -0.168258
# 90   0.452203 -0.201681
# 95  -0.739247  1.631635
# 116 -0.134777 -0.003208
# 131 -0.034223  0.116170
# 182  0.480198 -0.296339
# 254  0.252205 -0.379673
# 261 -1.260071  2.239118
# 288  0.477742 -0.310819
# 292  0.180568 -0.434438
# 307  0.151187 -0.300603
# 392  0.208464 -0.030021
# 431 -3.139842 -2.231226
# 436  0.353134 -0.087622
# 473  0.256233 -0.137886
# 508 -1.494302 -0.657081
# 521 -0.652956  1.064913
# 545  0.478850 -0.334016
# 699  0.496169 -0.180943
# 763  0.371987 -0.062680
# 946  0.179586  0.330204
# 968  0.503052 -0.152739
# 991  0.269269  0.164825

# %%
result_c
# Out:
#                          0             1
# その他日用品        0.000000e+00  0.000000e+00
# その他食品        -3.555522e+00 -2.583948e+00
# ペット用品        -1.803574e-01  6.968505e-01
# 加工食品          3.538896e-01 -2.543429e-01
# 化粧品          -6.074400e-02  4.086190e-01
# 家具           -8.672414e-01  1.439997e+00
# 家庭用品         -9.241017e-01  1.705139e+00
# 家電            3.576377e-01  2.228803e-01
# 寝具・寝装品        5.882119e-03  0.000000e+00
# 文具・事務用品・情報文具 -8.599684e-01  1.804222e+00
# 日用雑貨         -1.322028e+00 -3.875784e-01
# 書籍           -8.867120e-01 -8.949992e-01
# 玩具            0.000000e+00  0.000000e+00
# 生鮮食品          3.919667e-01 -2.979101e-01
# 菓子類           3.595305e-01 -1.550246e-01
# 衣料・衣服         3.940811e-01 -4.754739e-01
# 車両用品         -1.930312e-30 -5.760896e-30
# 靴・履物         -2.858347e-30 -6.417201e-30
# 飲料・酒類         3.809091e-01 -1.082374e-01
# ＤＩＹ用品         3.576377e-01  2.228803e-01
# ＯＴＣ医薬品類      -1.092974e+00  2.149663e+00

# %%
contribution_ratio
# Out:
#               0         1
# 寄与率    0.228843  0.220778
# 累積寄与率  0.228843  0.449621

# %%
#散布図の設定
fig = plt.figure(figsize=[5,5])
ax = fig.add_subplot(1,1,1)
plt.xlim(-3.6, 3.6)
plt.ylim(-3.6, 3.6)

# 行スコア
plt.scatter(result_r[0].values, result_r[1].values, marker='o', color='black')
for i, j in result_r.iterrows():
    ax.annotate(i, xy =(j[0]+0.01,j[1]+0.01))

# 列スコア
plt.scatter(result_c[0].values, result_c[1].values, marker='x', color='gray')
for i, j in result_c.iterrows():
    ax.annotate(i, xy =(j[0]+0.01,j[1]+0.01))

#軸と軸ラベルの表示
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.xlabel('第1軸')
plt.ylabel('第2軸')

#plt.savefig('out/corresp_result.eps', bbox_inches='tight', dpi=600)
# Out:
# Text(0, 0.5, '第2軸')
